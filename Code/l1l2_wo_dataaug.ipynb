# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
zip = ZipFile('/content/drive/MyDrive/Tech_seminar/Data.zip')
zip.extractall()

# %%
import cv2
import subprocess
import numpy as np
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from sklearn.model_selection import train_test_split
from keras.layers import Convolution2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
from keras.utils.vis_utils import plot_model
from keras import models
from keras.layers import LeakyReLU
from keras import layers
from keras import optimizers

# %%
import cv2
import subprocess
import numpy as np
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l1

# %%
w, h = 128, 128
c = 3
batch_size = 16
no_epochs = 1000
validation_split = 0.2
verbosity = 1
max_norm_value = 2.0
number_of_visualizations = 6
input_shape = (w, h, c)

# %%
import os
def load_dataset():
  X = list()
  Y = list()
  # for folder in os.listdir('/content/Gender/Men'):
  for filename in os.listdir('/content/Data/Train/Cat'):
    img = cv2.imread('/content/Data/Train/Cat/' + filename, cv2.IMREAD_COLOR)
    RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    RGB_img = cv2.resize(RGB_img, (w, h), cv2.INTER_AREA)
    X.append(RGB_img)
    Y.append('0')
  for filename in os.listdir('/content/Data/Train/Dog'):
    img = cv2.imread('/content/Data/Train/Dog/' + filename, cv2.IMREAD_COLOR)
    RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    RGB_img = cv2.resize(RGB_img, (w, h), cv2.INTER_AREA)
    X.append(RGB_img)
    Y.append('1')
  X = np.array(X)
  Y = np.array(Y)
  X = X.astype('float32') / 255.0
  Y = keras.utils.to_categorical(Y, 2)
  trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)
  return trainX, trainY, testX, testY

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, w, h)
else:
    input_shape = (w, h, 3)

# %%
import tensorflow as tf

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape, kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# activation_18 (Activation)   (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# activation_19 (Activation)   (None, 61, 61, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_20 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                802880
# _________________________________________________________________
# activation_21 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# _________________________________________________________________
# activation_22 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 831,650
# Trainable params: 831,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical
trainX, trainY, testX, testY = load_dataset()

# %%
model = define_model(trainX)
model.summary()
print(len(trainX))

# %%
import matplotlib.pyplot as plt
print(testY[1])
img1 = (testX[1] * 255).astype(np.uint8)
img1 = img1.reshape(128, 128, 3)
plt.imshow(img1)
# Out:
# [0. 1.]

# %%
# opt = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)

# model.compile(
#     optimizer=opt,
#   loss='binary_crossentropy',
#   metrics=['accuracy'])
early_stopping = EarlyStopping(patience=5, verbose=1)
model_checkpoint = ModelCheckpoint("l2_wo_dataaug.model", verbose=1 , save_best_only=True)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=2, min_lr=0.00001, verbose=1)

# %%
history = model.fit(trainX, trainY, shuffle=True, epochs=no_epochs, batch_size=16, validation_split = validation_split, callbacks=[model_checkpoint, early_stopping, reduce_lr], verbose=1)
model.save('l2_wo_dataaug.model')
# Out:
# Epoch 1/1000
# 80/80 [==============================] - 26s 313ms/step - loss: 0.7686 - accuracy: 0.4648 - val_loss: 0.7128 - val_accuracy: 0.5437
#
# Epoch 00001: val_loss improved from inf to 0.71284, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 2/1000
# 80/80 [==============================] - 25s 314ms/step - loss: 0.7177 - accuracy: 0.5174 - val_loss: 0.7034 - val_accuracy: 0.5312
#
# Epoch 00002: val_loss improved from 0.71284 to 0.70336, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 3/1000
# 80/80 [==============================] - 25s 312ms/step - loss: 0.6946 - accuracy: 0.6044 - val_loss: 0.6945 - val_accuracy: 0.6094
#
# Epoch 00003: val_loss improved from 0.70336 to 0.69446, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 4/1000
# 80/80 [==============================] - 25s 311ms/step - loss: 0.6610 - accuracy: 0.6683 - val_loss: 0.6818 - val_accuracy: 0.6219
#
# Epoch 00004: val_loss improved from 0.69446 to 0.68182, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 5/1000
# 80/80 [==============================] - 25s 313ms/step - loss: 0.6429 - accuracy: 0.6745 - val_loss: 0.6940 - val_accuracy: 0.6313
#
# Epoch 00005: val_loss did not improve from 0.68182
# Epoch 6/1000
# 80/80 [==============================] - 25s 315ms/step - loss: 0.5658 - accuracy: 0.7335 - val_loss: 0.7066 - val_accuracy: 0.6281
#
# Epoch 00006: val_loss did not improve from 0.68182
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/1000
# 80/80 [==============================] - 25s 315ms/step - loss: 0.4917 - accuracy: 0.7835 - val_loss: 0.6755 - val_accuracy: 0.6500
#
# Epoch 00007: val_loss improved from 0.68182 to 0.67549, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 8/1000
# 80/80 [==============================] - 25s 315ms/step - loss: 0.4634 - accuracy: 0.7926 - val_loss: 0.6873 - val_accuracy: 0.6562
#
# Epoch 00008: val_loss did not improve from 0.67549
# Epoch 9/1000
# 80/80 [==============================] - 25s 314ms/step - loss: 0.4591 - accuracy: 0.8008 - val_loss: 0.6734 - val_accuracy: 0.6625
#
# Epoch 00009: val_loss improved from 0.67549 to 0.67343, saving model to l2_wo_dataaug.model
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets
# Epoch 10/1000
# 80/80 [==============================] - 25s 312ms/step - loss: 0.4427 - accuracy: 0.8030 - val_loss: 0.6956 - val_accuracy: 0.6500
#
# Epoch 00010: val_loss did not improve from 0.67343
# Epoch 11/1000
# 80/80 [==============================] - 25s 314ms/step - loss: 0.4450 - accuracy: 0.8003 - val_loss: 0.7035 - val_accuracy: 0.6750
#
# Epoch 00011: val_loss did not improve from 0.67343
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 12/1000
# 80/80 [==============================] - 25s 313ms/step - loss: 0.4293 - accuracy: 0.8214 - val_loss: 0.6872 - val_accuracy: 0.6812
#
# Epoch 00012: val_loss did not improve from 0.67343
# Epoch 13/1000
# 80/80 [==============================] - 25s 312ms/step - loss: 0.4161 - accuracy: 0.8221 - val_loss: 0.6756 - val_accuracy: 0.6812
#
# Epoch 00013: val_loss did not improve from 0.67343
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 14/1000
# 80/80 [==============================] - 26s 330ms/step - loss: 0.4077 - accuracy: 0.8375 - val_loss: 0.6771 - val_accuracy: 0.6719
#
# Epoch 00014: val_loss did not improve from 0.67343
# Epoch 00014: early stopping
# INFO:tensorflow:Assets written to: l2_wo_dataaug.model/assets

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('/content/l2_wo_dataaug.model')
predicted_score = model1.predict(testX)
score = model1.evaluate(testX, testY)
print("test loss, test acc:", score)
# Out:
# 13/13 [==============================] - 2s 148ms/step - loss: 0.7069 - accuracy: 0.6650
# test loss, test acc: [0.7069144248962402, 0.6650000214576721]

# %%
predicted_score

# %%
(trainx, trainy), (testx, testy) = mnist.load_data()
# trainx = trainx.reshape((trainx.shape[0], w, h, c))
# testx = testx.reshape((testx.shape[0], w, h, c))
# # one hot encode target values
# # trainY = to_categorical(trainY)
# # testY = to_categorical(testY)
# trainx = trainx.astype('float32') / 255.0
# testx = testx.astype('float32') / 255.0

# %%
img = testX[0].reshape(1, 28, 28, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-148771a156b2> in <module>()
# ----> 1 img = testX[0].reshape(1, 28, 28, 1)
#
# ValueError: cannot reshape array of size 12288 into shape (1,28,28,1)

# %%
y = testX[0]

# %%
n = 2
img1 = (testX[n] * 255).astype(np.uint8)
img1 = img1.reshape(128,128,3)
plt.imshow(img1)
# img = np.expand_dims(trainx[1], axis=0)
# img = img.astype('float32')
# img = testx[0].reshape(1,testx[0].shape)
img = testX[n].reshape(1, 128, 128, 3)
x = model1.predict(img)
print(x)
print(testY[n])
# Out:
# [[0.68136436 0.27889046]]
# [1. 0.]
