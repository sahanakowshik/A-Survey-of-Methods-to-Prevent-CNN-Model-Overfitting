# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
zip = ZipFile('/content/drive/MyDrive/Tech_seminar/Data.zip')
zip.extractall()

# %%
from zipfile import ZipFile
zip = ZipFile('/content/drive/MyDrive/Tech_seminar/test.zip')
zip.extractall()

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow import keras

# %%
img_width, img_height = 128, 128

train_data_dir = '/content/Data/Train'
validation_data_dir = '/content/Data/Validation'
nb_train_samples = 2000
nb_validation_samples = 800
epochs = 50
batch_size = 16

# %%
import tensorflow as tf

# %%
import keras.backend as K
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape, kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.01, l2=0.01)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 126, 126, 32)      896
# _________________________________________________________________
# activation_20 (Activation)   (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# activation_21 (Activation)   (None, 61, 61, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# activation_22 (Activation)   (None, 28, 28, 64)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                802880
# _________________________________________________________________
# activation_23 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_24 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 831,585
# Trainable params: 831,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)


test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
early_stopping = EarlyStopping(patience=10, verbose=1)
model_checkpoint = ModelCheckpoint("data_augment_l1_l2_2.model", verbose=1 , save_best_only=True)
reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000001, verbose=1)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=80,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size,
    callbacks=[model_checkpoint, early_stopping, reduce_lr])
# model.save('data_augment_l1.model')
# Out:
# Epoch 1/80
# 125/125 [==============================] - 52s 406ms/step - loss: 1.3254 - accuracy: 0.4940 - val_loss: 0.8123 - val_accuracy: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.81231, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 2/80
# 125/125 [==============================] - 50s 397ms/step - loss: 0.7806 - accuracy: 0.5213 - val_loss: 0.7124 - val_accuracy: 0.5462
#
# Epoch 00002: val_loss improved from 0.81231 to 0.71244, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 3/80
# 125/125 [==============================] - 49s 395ms/step - loss: 0.7200 - accuracy: 0.5393 - val_loss: 0.6961 - val_accuracy: 0.5900
#
# Epoch 00003: val_loss improved from 0.71244 to 0.69614, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 4/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.6999 - accuracy: 0.5600 - val_loss: 0.6790 - val_accuracy: 0.6338
#
# Epoch 00004: val_loss improved from 0.69614 to 0.67895, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 5/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.6871 - accuracy: 0.5958 - val_loss: 0.6551 - val_accuracy: 0.6675
#
# Epoch 00005: val_loss improved from 0.67895 to 0.65508, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 6/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.6664 - accuracy: 0.6363 - val_loss: 0.6593 - val_accuracy: 0.6288
#
# Epoch 00006: val_loss did not improve from 0.65508
# Epoch 7/80
# 125/125 [==============================] - 49s 394ms/step - loss: 0.6384 - accuracy: 0.6761 - val_loss: 0.6246 - val_accuracy: 0.7000
#
# Epoch 00007: val_loss improved from 0.65508 to 0.62464, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 8/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.6357 - accuracy: 0.6805 - val_loss: 0.6279 - val_accuracy: 0.6662
#
# Epoch 00008: val_loss did not improve from 0.62464
# Epoch 9/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.6143 - accuracy: 0.6869 - val_loss: 0.6092 - val_accuracy: 0.6875
#
# Epoch 00009: val_loss improved from 0.62464 to 0.60924, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 10/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.6085 - accuracy: 0.6870 - val_loss: 0.6040 - val_accuracy: 0.7050
#
# Epoch 00010: val_loss improved from 0.60924 to 0.60397, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 11/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.6004 - accuracy: 0.7015 - val_loss: 0.5984 - val_accuracy: 0.6988
#
# Epoch 00011: val_loss improved from 0.60397 to 0.59844, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 12/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.5984 - accuracy: 0.6985 - val_loss: 0.5914 - val_accuracy: 0.7050
#
# Epoch 00012: val_loss improved from 0.59844 to 0.59139, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 13/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.5898 - accuracy: 0.7201 - val_loss: 0.6061 - val_accuracy: 0.7150
#
# Epoch 00013: val_loss did not improve from 0.59139
# Epoch 14/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.5674 - accuracy: 0.7342 - val_loss: 0.5872 - val_accuracy: 0.7050
#
# Epoch 00014: val_loss improved from 0.59139 to 0.58722, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 15/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.5582 - accuracy: 0.7381 - val_loss: 0.5736 - val_accuracy: 0.7175
#
# Epoch 00015: val_loss improved from 0.58722 to 0.57357, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 16/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.5495 - accuracy: 0.7459 - val_loss: 0.6122 - val_accuracy: 0.7200
#
# Epoch 00016: val_loss did not improve from 0.57357
# Epoch 17/80
# 125/125 [==============================] - 49s 391ms/step - loss: 0.5576 - accuracy: 0.7288 - val_loss: 0.5802 - val_accuracy: 0.7212
#
# Epoch 00017: val_loss did not improve from 0.57357
# Epoch 18/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.5511 - accuracy: 0.7365 - val_loss: 0.5645 - val_accuracy: 0.7287
#
# Epoch 00018: val_loss improved from 0.57357 to 0.56450, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 19/80
# 125/125 [==============================] - 49s 390ms/step - loss: 0.5327 - accuracy: 0.7526 - val_loss: 0.5509 - val_accuracy: 0.7325
#
# Epoch 00019: val_loss improved from 0.56450 to 0.55090, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 20/80
# 125/125 [==============================] - 49s 394ms/step - loss: 0.5331 - accuracy: 0.7519 - val_loss: 0.6069 - val_accuracy: 0.7163
#
# Epoch 00020: val_loss did not improve from 0.55090
# Epoch 21/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.5052 - accuracy: 0.7627 - val_loss: 0.5566 - val_accuracy: 0.7375
#
# Epoch 00021: val_loss did not improve from 0.55090
# Epoch 22/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.5157 - accuracy: 0.7660 - val_loss: 0.5423 - val_accuracy: 0.7525
#
# Epoch 00022: val_loss improved from 0.55090 to 0.54230, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 23/80
# 125/125 [==============================] - 50s 395ms/step - loss: 0.5292 - accuracy: 0.7558 - val_loss: 0.5911 - val_accuracy: 0.7212
#
# Epoch 00023: val_loss did not improve from 0.54230
# Epoch 24/80
# 125/125 [==============================] - 49s 394ms/step - loss: 0.4994 - accuracy: 0.7796 - val_loss: 0.6216 - val_accuracy: 0.7000
#
# Epoch 00024: val_loss did not improve from 0.54230
# Epoch 25/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.5206 - accuracy: 0.7601 - val_loss: 0.5757 - val_accuracy: 0.7400
#
# Epoch 00025: val_loss did not improve from 0.54230
# Epoch 26/80
# 125/125 [==============================] - 49s 395ms/step - loss: 0.5120 - accuracy: 0.7723 - val_loss: 0.6035 - val_accuracy: 0.7150
#
# Epoch 00026: val_loss did not improve from 0.54230
# Epoch 27/80
# 125/125 [==============================] - 49s 393ms/step - loss: 0.5138 - accuracy: 0.7809 - val_loss: 0.5888 - val_accuracy: 0.7188
#
# Epoch 00027: val_loss did not improve from 0.54230
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 28/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.4795 - accuracy: 0.7808 - val_loss: 0.5369 - val_accuracy: 0.7638
#
# Epoch 00028: val_loss improved from 0.54230 to 0.53686, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 29/80
# 125/125 [==============================] - 49s 392ms/step - loss: 0.4203 - accuracy: 0.8261 - val_loss: 0.5306 - val_accuracy: 0.7688
#
# Epoch 00029: val_loss improved from 0.53686 to 0.53057, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 30/80
# 125/125 [==============================] - 49s 390ms/step - loss: 0.4312 - accuracy: 0.8027 - val_loss: 0.5364 - val_accuracy: 0.7725
#
# Epoch 00030: val_loss did not improve from 0.53057
# Epoch 31/80
# 125/125 [==============================] - 49s 390ms/step - loss: 0.4375 - accuracy: 0.8102 - val_loss: 0.5309 - val_accuracy: 0.7638
#
# Epoch 00031: val_loss did not improve from 0.53057
# Epoch 32/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4171 - accuracy: 0.8284 - val_loss: 0.5179 - val_accuracy: 0.7700
#
# Epoch 00032: val_loss improved from 0.53057 to 0.51789, saving model to data_augment_l1_l2_2.model
# INFO:tensorflow:Assets written to: data_augment_l1_l2_2.model/assets
# Epoch 33/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4175 - accuracy: 0.8133 - val_loss: 0.5333 - val_accuracy: 0.7700
#
# Epoch 00033: val_loss did not improve from 0.51789
# Epoch 34/80
# 125/125 [==============================] - 48s 386ms/step - loss: 0.4233 - accuracy: 0.8193 - val_loss: 0.5284 - val_accuracy: 0.7763
#
# Epoch 00034: val_loss did not improve from 0.51789
# Epoch 35/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4255 - accuracy: 0.8134 - val_loss: 0.5335 - val_accuracy: 0.7750
#
# Epoch 00035: val_loss did not improve from 0.51789
# Epoch 36/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.3894 - accuracy: 0.8368 - val_loss: 0.5216 - val_accuracy: 0.7775
#
# Epoch 00036: val_loss did not improve from 0.51789
# Epoch 37/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4196 - accuracy: 0.8148 - val_loss: 0.5321 - val_accuracy: 0.7775
#
# Epoch 00037: val_loss did not improve from 0.51789
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 38/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4085 - accuracy: 0.8275 - val_loss: 0.5276 - val_accuracy: 0.7738
#
# Epoch 00038: val_loss did not improve from 0.51789
# Epoch 39/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.4080 - accuracy: 0.8205 - val_loss: 0.5258 - val_accuracy: 0.7700
#
# Epoch 00039: val_loss did not improve from 0.51789
# Epoch 40/80
# 125/125 [==============================] - 48s 386ms/step - loss: 0.4098 - accuracy: 0.8207 - val_loss: 0.5251 - val_accuracy: 0.7713
#
# Epoch 00040: val_loss did not improve from 0.51789
# Epoch 41/80
# 125/125 [==============================] - 49s 388ms/step - loss: 0.4105 - accuracy: 0.8278 - val_loss: 0.5229 - val_accuracy: 0.7750
#
# Epoch 00041: val_loss did not improve from 0.51789
# Epoch 42/80
# 125/125 [==============================] - 48s 387ms/step - loss: 0.3931 - accuracy: 0.8456 - val_loss: 0.5240 - val_accuracy: 0.7775
#
# Epoch 00042: val_loss did not improve from 0.51789
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00042: early stopping

# %%
model.fit_generator(datagen, epochs=no_epochs, callbacks=[model_checkpoint, early_stopping, reduce_lr], verbose=1)
model.save('data_augment.model')

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model1 = load_model('/content/data_augment_l2.model')
# predicted_score = model1.predict(testX)
# score = model1.evaluate(testX, testY)
# print("test loss, test acc:", score)

# %%
import os
import cv2
import numpy as np
test = []
for filename in os.listdir('/content/test'):
    img = cv2.imread('/content/test/' + filename, cv2.IMREAD_COLOR)
    RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    RGB_img = cv2.resize(RGB_img, (128, 128), cv2.INTER_AREA)
    test.append(RGB_img)
    test.append(RGB_img)

# %%
test = np.array(test)
test = test.astype('float32') / 255.0

# %%
n = 47
img1 = (test[n] * 255).astype(np.uint8)
img1 = img1.reshape(128,128,3)
plt.imshow(img1)
# img = np.expand_dims(trainx[1], axis=0)
# img = img.astype('float32')
# img = testx[0].reshape(1,testx[0].shape)
img = test[n].reshape(1, 128, 128, 3)
x = model.predict(img)
print(x)
# Out:
# [[0.16973433]]
